# %%
#Function
#perform a specific task block of statement which it is self contained block
#Advantage
#1.Reusability
#2.Readability
 #type
 #1.Built in function(library function),print(),Range(),type()
 #2.Use define function
#syntax
#def(fun_name):
   #statement

# %%
def square (num):
    ans=num*num
    print("square is ",ans)
num=int(input("Enter a number :"))
square(num)
# Out:
# Enter a number : 5
# square is  25

# %%
def add (x,y):
    z=x+y
    return z
x=int(input("Enter a number for x:"))
y=int(input("Enter a number for y:"))
print ("Addition of x And y is :",add(x,y))
# Out:
# Enter a number for x: 5
# Enter a number for y: 2
# Addition of x And y is : 7

# %%
#Write a function compare() to compare two number
def compare(a,b):
    if a > b :
        print("a is greather than b")
    elif b > a:
        print("b is grether than a")
    else:
        print("Both are same")
a=int(input("Enter a number a :"))
b=int(input("Enter a number b :"))
compare(a,b)
# Out:
# Enter a number a : 23
# Enter a number b : 20
# a is greather than b

# %%
#write a function of table() to print table of given number
def table(number):
    for i in range(1,11):
        print(number,"*",i,"=",number*i)
number=int(input("ENter a number :"))
table(number)
# Out:
# ENter a number : 29
# 29 * 1 = 29
# 29 * 2 = 58
# 29 * 3 = 87
# 29 * 4 = 116
# 29 * 5 = 145
# 29 * 6 = 174
# 29 * 7 = 203
# 29 * 8 = 232
# 29 * 9 = 261
# 29 * 10 = 290

# %%
#function with defult argument
def add (x=10,y=20):
    z=x+y
    return z
add()
add(5)
add(5,5)
# Out:
# 10

# %%
#write a function rev_number to print number in reverse order

# %%
#write a function count_vowel from a given string
v=("Vishal Jadhav")
for i in v:
    if a , i, o, u, e

# %%
#write a function count_vowel from a given string
def count_vowel(input_string):
    vowels = "aeiouAEIOU"  # Both lowercase and uppercase vowels
    count = 0
    
    for char in input_string:
        if char in vowels:
            count += 1    
# Example usage
input_string = "Vishal jadhav











































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































"
print(f"Number of vowels: {count_vowel(input_string)}")
# Out:
# Number of vowels: None
